# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/present/blob/master/WUSTL/CABI-Demand/demand_seasonality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Washington University [Olin School of Business](https://olin.wustl.edu/EN-US/Pages/default.aspx)
# [Center for Analytics and Business Insights](https://olin.wustl.edu/EN-US/Faculty-Research/research-centers/center-analytics-business-insights/Pages/default.aspx) (CABI)
# [Deep Learning for Demand Forecasting](https://github.com/jeffheaton/present/tree/master/WUSTL/CABI-Demand)
# Copyright 2022 by [Jeff Heaton](https://www.youtube.com/c/HeatonResearch), Released under [CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/)
#
# # Dealing with Seasonality
#
# Connect GDrive, to write out any results.

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab

# %% [markdown]
# Read the provided tabular data CSVs.

# %%
import pandas as pd
import os

df_sales = pd.read_csv("https://data.heatonresearch.com/wustl/CABI/demand-forecast/sales_train.csv")
df_items = pd.read_csv("https://data.heatonresearch.com/wustl/CABI/demand-forecast/items.csv")
df_resturant = pd.read_csv("https://data.heatonresearch.com/wustl/CABI/demand-forecast/resturants.csv")

df_sales.date = pd.to_datetime(df_sales.date, errors='coerce') 
df_sales['weekday'] = df_sales.date.dt.day_name()

start_date = df_sales.date.min()
df_sales['week'] = (((df_sales.date - start_date).dt.days)/7).astype(int)

# %% [markdown]
# Begin by producing a line graph of all sales over the provided 3-year timespan.

# %%
import plotly.express as px

df_plot = df_sales[['date','item_count']].groupby(['date']).mean().reset_index()
fig = px.line(df_plot, x="date", y="item_count", title='RAW Sales by Date')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3df47bab-82a9-4b5d-9f7c-1a2b02f01f20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3df47bab-82a9-4b5d-9f7c-1a2b02f01f20")) {                    Plotly.newPlot(                        "3df47bab-82a9-4b5d-9f7c-1a2b02f01f20",                        [{"hovertemplate":"date=%{x}<br>item_count=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2019-01-01T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-05T00:00:00","2019-01-06T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-12T00:00:00","2019-01-13T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-19T00:00:00","2019-01-20T00:00:00","2019-01-21T00:00:00","2019-01-22T00:00:00","2019-01-23T00:00:00","2019-01-24T00:00:00","2019-01-25T00:00:00","2019-01-26T00:00:00","2019-01-27T00:00:00","2019-01-28T00:00:00","2019-01-29T00:00:00","2019-01-30T00:00:00","2019-01-31T00:00:00","2019-02-01T00:00:00","2019-02-02T00:00:00","2019-02-03T00:00:00","2019-02-04T00:00:00","2019-02-05T00:00:00","2019-02-06T00:00:00","2019-02-07T00:00:00","2019-02-08T00:00:00","2019-02-09T00:00:00","2019-02-10T00:00:00","2019-02-11T00:00:00","2019-02-12T00:00:00","2019-02-13T00:00:00","2019-02-14T00:00:00","2019-02-15T00:00:00","2019-02-16T00:00:00","2019-02-17T00:00:00","2019-02-18T00:00:00","2019-02-19T00:00:00","2019-02-20T00:00:00","2019-02-21T00:00:00","2019-02-22T00:00:00","2019-02-23T00:00:00","2019-02-24T00:00:00","2019-02-25T00:00:00","2019-02-26T00:00:00","2019-02-27T00:00:00","2019-02-28T00:00:00","2019-03-01T00:00:00","2019-03-02T00:00:00","2019-03-03T00:00:00","2019-03-04T00:00:00","2019-03-05T00:00:00","2019-03-06T00:00:00","2019-03-07T00:00:00","2019-03-08T00:00:00","2019-03-09T00:00:00","2019-03-10T00:00:00","2019-03-11T00:00:00","2019-03-12T00:00:00","2019-03-13T00:00:00","2019-03-14T00:00:00","2019-03-15T00:00:00","2019-03-16T00:00:00","2019-03-17T00:00:00","2019-03-18T00:00:00","2019-03-19T00:00:00","2019-03-20T00:00:00","2019-03-21T00:00:00","2019-03-22T00:00:00","2019-03-23T00:00:00","2019-03-24T00:00:00","2019-03-25T00:00:00","2019-03-26T00:00:00","2019-03-27T00:00:00","2019-03-28T00:00:00","2019-03-29T00:00:00","2019-03-30T00:00:00","2019-03-31T00:00:00","2019-04-01T00:00:00","2019-04-02T00:00:00","2019-04-03T00:00:00","2019-04-04T00:00:00","2019-04-05T00:00:00","2019-04-06T00:00:00","2019-04-07T00:00:00","2019-04-08T00:00:00","2019-04-09T00:00:00","2019-04-10T00:00:00","2019-04-11T00:00:00","2019-04-12T00:00:00","2019-04-13T00:00:00","2019-04-14T00:00:00","2019-04-15T00:00:00","2019-04-16T00:00:00","2019-04-17T00:00:00","2019-04-18T00:00:00","2019-04-19T00:00:00","2019-04-20T00:00:00","2019-04-21T00:00:00","2019-04-22T00:00:00","2019-04-23T00:00:00","2019-04-24T00:00:00","2019-04-25T00:00:00","2019-04-26T00:00:00","2019-04-27T00:00:00","2019-04-28T00:00:00","2019-04-29T00:00:00","2019-04-30T00:00:00","2019-05-01T00:00:00","2019-05-02T00:00:00","2019-05-03T00:00:00","2019-05-04T00:00:00","2019-05-05T00:00:00","2019-05-06T00:00:00","2019-05-07T00:00:00","2019-05-08T00:00:00","2019-05-09T00:00:00","2019-05-10T00:00:00","2019-05-11T00:00:00","2019-05-12T00:00:00","2019-05-13T00:00:00","2019-05-14T00:00:00","2019-05-15T00:00:00","2019-05-16T00:00:00","2019-05-17T00:00:00","2019-05-18T00:00:00","2019-05-19T00:00:00","2019-05-20T00:00:00","2019-05-21T00:00:00","2019-05-22T00:00:00","2019-05-23T00:00:00","2019-05-24T00:00:00","2019-05-25T00:00:00","2019-05-26T00:00:00","2019-05-27T00:00:00","2019-05-28T00:00:0 ...

# %% [markdown]
# ### Detrending
#
# Can you see an overall trend in this data?  Beyond just the seasonality?

# %%
from scipy import signal

df_plot.item_count = signal.detrend(df_plot.item_count)

fig = px.line(df_plot, x="date", y="item_count", title='RAW Sales by Date')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8149ef6d-c9b7-402f-99c2-f9390dd0eabf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8149ef6d-c9b7-402f-99c2-f9390dd0eabf")) {                    Plotly.newPlot(                        "8149ef6d-c9b7-402f-99c2-f9390dd0eabf",                        [{"hovertemplate":"date=%{x}<br>item_count=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2019-01-01T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-05T00:00:00","2019-01-06T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-12T00:00:00","2019-01-13T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-19T00:00:00","2019-01-20T00:00:00","2019-01-21T00:00:00","2019-01-22T00:00:00","2019-01-23T00:00:00","2019-01-24T00:00:00","2019-01-25T00:00:00","2019-01-26T00:00:00","2019-01-27T00:00:00","2019-01-28T00:00:00","2019-01-29T00:00:00","2019-01-30T00:00:00","2019-01-31T00:00:00","2019-02-01T00:00:00","2019-02-02T00:00:00","2019-02-03T00:00:00","2019-02-04T00:00:00","2019-02-05T00:00:00","2019-02-06T00:00:00","2019-02-07T00:00:00","2019-02-08T00:00:00","2019-02-09T00:00:00","2019-02-10T00:00:00","2019-02-11T00:00:00","2019-02-12T00:00:00","2019-02-13T00:00:00","2019-02-14T00:00:00","2019-02-15T00:00:00","2019-02-16T00:00:00","2019-02-17T00:00:00","2019-02-18T00:00:00","2019-02-19T00:00:00","2019-02-20T00:00:00","2019-02-21T00:00:00","2019-02-22T00:00:00","2019-02-23T00:00:00","2019-02-24T00:00:00","2019-02-25T00:00:00","2019-02-26T00:00:00","2019-02-27T00:00:00","2019-02-28T00:00:00","2019-03-01T00:00:00","2019-03-02T00:00:00","2019-03-03T00:00:00","2019-03-04T00:00:00","2019-03-05T00:00:00","2019-03-06T00:00:00","2019-03-07T00:00:00","2019-03-08T00:00:00","2019-03-09T00:00:00","2019-03-10T00:00:00","2019-03-11T00:00:00","2019-03-12T00:00:00","2019-03-13T00:00:00","2019-03-14T00:00:00","2019-03-15T00:00:00","2019-03-16T00:00:00","2019-03-17T00:00:00","2019-03-18T00:00:00","2019-03-19T00:00:00","2019-03-20T00:00:00","2019-03-21T00:00:00","2019-03-22T00:00:00","2019-03-23T00:00:00","2019-03-24T00:00:00","2019-03-25T00:00:00","2019-03-26T00:00:00","2019-03-27T00:00:00","2019-03-28T00:00:00","2019-03-29T00:00:00","2019-03-30T00:00:00","2019-03-31T00:00:00","2019-04-01T00:00:00","2019-04-02T00:00:00","2019-04-03T00:00:00","2019-04-04T00:00:00","2019-04-05T00:00:00","2019-04-06T00:00:00","2019-04-07T00:00:00","2019-04-08T00:00:00","2019-04-09T00:00:00","2019-04-10T00:00:00","2019-04-11T00:00:00","2019-04-12T00:00:00","2019-04-13T00:00:00","2019-04-14T00:00:00","2019-04-15T00:00:00","2019-04-16T00:00:00","2019-04-17T00:00:00","2019-04-18T00:00:00","2019-04-19T00:00:00","2019-04-20T00:00:00","2019-04-21T00:00:00","2019-04-22T00:00:00","2019-04-23T00:00:00","2019-04-24T00:00:00","2019-04-25T00:00:00","2019-04-26T00:00:00","2019-04-27T00:00:00","2019-04-28T00:00:00","2019-04-29T00:00:00","2019-04-30T00:00:00","2019-05-01T00:00:00","2019-05-02T00:00:00","2019-05-03T00:00:00","2019-05-04T00:00:00","2019-05-05T00:00:00","2019-05-06T00:00:00","2019-05-07T00:00:00","2019-05-08T00:00:00","2019-05-09T00:00:00","2019-05-10T00:00:00","2019-05-11T00:00:00","2019-05-12T00:00:00","2019-05-13T00:00:00","2019-05-14T00:00:00","2019-05-15T00:00:00","2019-05-16T00:00:00","2019-05-17T00:00:00","2019-05-18T00:00:00","2019-05-19T00:00:00","2019-05-20T00:00:00","2019-05-21T00:00:00","2019-05-22T00:00:00","2019-05-23T00:00:00","2019-05-24T00:00:00","2019-05-25T00:00:00","2019-05-26T00:00:00","2019-05-27T00:00:00","2019-05-28T00:00:0 ...

# %% [markdown]
# ### De-Seasoning
#
# Lets remove the seasonality.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot

df_plot = df_sales[['date','item_count']].groupby(['date']).mean()

# extrapolate_trend='freq',
adjustment = seasonal_decompose(df_plot.item_count, model='multiplicative') # , model='additive', period=7

# multiplicative
# additive

adjustment.plot()
pyplot.show()

# %% [markdown]
# Notice how the yearly seasonality was detected as the trend? The weekly seasonality was detected as seasonal.  Without zooming you cannot see the ups and downs of the individual days of the week.

# %%
adjustment.trend
# Out:
# date
# 2019-01-01         NaN
# 2019-01-02         NaN
# 2019-01-03         NaN
# 2019-01-04    3.920000
# 2019-01-05    3.672857
#                 ...
# 2021-12-27    4.610000
# 2021-12-28    4.537143
# 2021-12-29         NaN
# 2021-12-30         NaN
# 2021-12-31         NaN
# Name: trend, Length: 1096, dtype: float64

# %%
adjustment.seasonal
# Out:
# date
# 2019-01-01    0.787740
# 2019-01-02    0.884056
# 2019-01-03    1.186132
# 2019-01-04    1.390103
# 2019-01-05    1.389816
#                 ...
# 2021-12-27    0.693107
# 2021-12-28    0.787740
# 2021-12-29    0.884056
# 2021-12-30    1.186132
# 2021-12-31    1.390103
# Name: seasonal, Length: 1096, dtype: float64

# %% [markdown]
# ### Resulting Dataset
#
# Lets see the dataset "flattened".

# %%
df_plot2 = df_plot.copy()

df_plot2.item_count = df_plot2.item_count / adjustment.seasonal / adjustment.trend

fig = px.line(df_plot2.reset_index(), x="date", y="item_count", title='RAW Sales by Date')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1aa2259c-4179-4fd3-b511-b44855a7c0df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1aa2259c-4179-4fd3-b511-b44855a7c0df")) {                    Plotly.newPlot(                        "1aa2259c-4179-4fd3-b511-b44855a7c0df",                        [{"hovertemplate":"date=%{x}<br>item_count=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2019-01-01T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-05T00:00:00","2019-01-06T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-12T00:00:00","2019-01-13T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-19T00:00:00","2019-01-20T00:00:00","2019-01-21T00:00:00","2019-01-22T00:00:00","2019-01-23T00:00:00","2019-01-24T00:00:00","2019-01-25T00:00:00","2019-01-26T00:00:00","2019-01-27T00:00:00","2019-01-28T00:00:00","2019-01-29T00:00:00","2019-01-30T00:00:00","2019-01-31T00:00:00","2019-02-01T00:00:00","2019-02-02T00:00:00","2019-02-03T00:00:00","2019-02-04T00:00:00","2019-02-05T00:00:00","2019-02-06T00:00:00","2019-02-07T00:00:00","2019-02-08T00:00:00","2019-02-09T00:00:00","2019-02-10T00:00:00","2019-02-11T00:00:00","2019-02-12T00:00:00","2019-02-13T00:00:00","2019-02-14T00:00:00","2019-02-15T00:00:00","2019-02-16T00:00:00","2019-02-17T00:00:00","2019-02-18T00:00:00","2019-02-19T00:00:00","2019-02-20T00:00:00","2019-02-21T00:00:00","2019-02-22T00:00:00","2019-02-23T00:00:00","2019-02-24T00:00:00","2019-02-25T00:00:00","2019-02-26T00:00:00","2019-02-27T00:00:00","2019-02-28T00:00:00","2019-03-01T00:00:00","2019-03-02T00:00:00","2019-03-03T00:00:00","2019-03-04T00:00:00","2019-03-05T00:00:00","2019-03-06T00:00:00","2019-03-07T00:00:00","2019-03-08T00:00:00","2019-03-09T00:00:00","2019-03-10T00:00:00","2019-03-11T00:00:00","2019-03-12T00:00:00","2019-03-13T00:00:00","2019-03-14T00:00:00","2019-03-15T00:00:00","2019-03-16T00:00:00","2019-03-17T00:00:00","2019-03-18T00:00:00","2019-03-19T00:00:00","2019-03-20T00:00:00","2019-03-21T00:00:00","2019-03-22T00:00:00","2019-03-23T00:00:00","2019-03-24T00:00:00","2019-03-25T00:00:00","2019-03-26T00:00:00","2019-03-27T00:00:00","2019-03-28T00:00:00","2019-03-29T00:00:00","2019-03-30T00:00:00","2019-03-31T00:00:00","2019-04-01T00:00:00","2019-04-02T00:00:00","2019-04-03T00:00:00","2019-04-04T00:00:00","2019-04-05T00:00:00","2019-04-06T00:00:00","2019-04-07T00:00:00","2019-04-08T00:00:00","2019-04-09T00:00:00","2019-04-10T00:00:00","2019-04-11T00:00:00","2019-04-12T00:00:00","2019-04-13T00:00:00","2019-04-14T00:00:00","2019-04-15T00:00:00","2019-04-16T00:00:00","2019-04-17T00:00:00","2019-04-18T00:00:00","2019-04-19T00:00:00","2019-04-20T00:00:00","2019-04-21T00:00:00","2019-04-22T00:00:00","2019-04-23T00:00:00","2019-04-24T00:00:00","2019-04-25T00:00:00","2019-04-26T00:00:00","2019-04-27T00:00:00","2019-04-28T00:00:00","2019-04-29T00:00:00","2019-04-30T00:00:00","2019-05-01T00:00:00","2019-05-02T00:00:00","2019-05-03T00:00:00","2019-05-04T00:00:00","2019-05-05T00:00:00","2019-05-06T00:00:00","2019-05-07T00:00:00","2019-05-08T00:00:00","2019-05-09T00:00:00","2019-05-10T00:00:00","2019-05-11T00:00:00","2019-05-12T00:00:00","2019-05-13T00:00:00","2019-05-14T00:00:00","2019-05-15T00:00:00","2019-05-16T00:00:00","2019-05-17T00:00:00","2019-05-18T00:00:00","2019-05-19T00:00:00","2019-05-20T00:00:00","2019-05-21T00:00:00","2019-05-22T00:00:00","2019-05-23T00:00:00","2019-05-24T00:00:00","2019-05-25T00:00:00","2019-05-26T00:00:00","2019-05-27T00:00:00","2019-05-28T00:00:0 ...

# %%
df_adjustment = pd.DataFrame(adjustment.seasonal)
df_adjustment['trend'] = adjustment.trend

# %%
df_adjustment
# Out:
#             seasonal     trend
# date
# 2019-01-01  0.787740       NaN
# 2019-01-02  0.884056       NaN
# 2019-01-03  1.186132       NaN
# 2019-01-04  1.390103  3.920000
# 2019-01-05  1.389816  3.672857
# ...              ...       ...
# 2021-12-27  0.693107  4.610000
# 2021-12-28  0.787740  4.537143
# 2021-12-29  0.884056       NaN
# 2021-12-30  1.186132       NaN
# 2021-12-31  1.390103       NaN
#
# [1096 rows x 2 columns]

# %% [markdown]
# We will save the adjustment table to a binary pickle form, so we can later reload it exactly as it is.  We will make use of this table during day 2.

# %%
df_adjustment.to_pickle("/content/drive/MyDrive/adjustment.pkl")

# %% [markdown]
# # Convert All Items
#
# Now that we've estimated seasonality and trend for the average of all items, we must apply this to the individual items.

# %%
df_sales_adj = df_sales.merge(df_adjustment,right_index=True,left_on="date")
df_sales_adj.dropna(inplace=True)
df_sales_adj['adjust'] = df_sales_adj.item_count / df_sales_adj.seasonal / df_sales_adj.trend

# %% [markdown]
# Compare the individual item plot to the previous example with seasonality still embeded.

# %%
SINGLE_YEAR = 2020

df_sales_single_year = df_sales_adj[df_sales['date'].dt.year == SINGLE_YEAR]
df_plot = df_sales_single_year[['date','item_id','adjust']].groupby(['date','item_id']).mean().reset_index()
df_plot = df_plot.merge(df_items,left_on="item_id",right_on="id")[['date','adjust','name']]
fig = px.bar(df_plot, x='date', y='adjust',color="name", title=f'Item Sales by Date - {SINGLE_YEAR}')
fig.update_layout(bargap=0.0,bargroupgap=0.0)
fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2a2078d8-c436-4155-b09e-5ea1d1c6173f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a2078d8-c436-4155-b09e-5ea1d1c6173f")) {                    Plotly.newPlot(                        "2a2078d8-c436-4155-b09e-5ea1d1c6173f",                        [{"alignmentgroup":"True","hovertemplate":"name=Chocolate Cake<br>date=%{x}<br>adjust=%{y}<extra></extra>","legendgroup":"Chocolate Cake","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Chocolate Cake","offsetgroup":"Chocolate Cake","orientation":"v","showlegend":true,"textposition":"auto","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00", ...

# %% [markdown]
# ## Model with Adjusted Data
#
# Now lets model, with this *mostly* cleaned up data.
#
# Utility function to create sequences.

# %%
def series_to_supervised(data, window=1, lag=1, dropnan=True):
    cols, names = list(), list()
    # Input sequence (t-n, ... t-1)
    for i in range(window, 0, -1):
        cols.append(data.shift(i))
        names += [('%s(t-%d)' % (col, i)) for col in data.columns]
    # Current timestep (t=0)
    cols.append(data)
    names += [('%s(t)' % (col)) for col in data.columns]
    # Target timestep (t=lag)
    cols.append(data.shift(-lag))
    names += [('%s(t+%d)' % (col, lag)) for col in data.columns]
    # Put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # Drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %% [markdown]
# We will link the season and trend adjustments.

# %%
df_items2 = df_items[['id','store_id']]
df_train = df_sales_adj.merge(df_items2,left_on='item_id',right_on='id')
df_train[['date','item_id','adjust','store_id','item_count','seasonal','trend']]

df_train = df_train.sort_values('date').groupby(['item_id', 'store_id', 'date'], as_index=False)
df_train = df_train.agg({'adjust':['mean'],'item_count':['mean'],'seasonal':['mean'],'trend':['mean']})
df_train.columns = ['item', 'store', 'date', 'adjust', 'item_count', 'seasonal', 'trend']
df_train.head()
# Out:
#    item  store       date  adjust  item_count  seasonal     trend
# 0     1      4 2019-01-04     0.0         0.0  1.390103  3.920000
# 1     1      4 2019-01-05     0.0         0.0  1.389816  3.672857
# 2     1      4 2019-01-06     0.0         0.0  0.669045  3.685714
# 3     1      4 2019-01-07     0.0         0.0  0.693107  3.695714
# 4     1      4 2019-01-08     0.0         0.0  0.787740  3.722857

# %% [markdown]
# Lets also engineer two features.  This gives the neural network some information about what day of the week and day of the year we are in. Ideally, these are not needed with seasonality generally removed; however, if some seasonality and trend remain, maybe these two features help the neural network to overcome.

# %%
df_train['dow'] = df_train['date'].dt.dayofweek
df_train['doy'] = df_train['date'].dt.dayofyear
df_train
# Out:
#         item  store       date  adjust  item_count  seasonal     trend  dow  \
# 0          1      4 2019-01-04     0.0         0.0  1.390103  3.920000    4
# 1          1      4 2019-01-05     0.0         0.0  1.389816  3.672857    5
# 2          1      4 2019-01-06     0.0         0.0  0.669045  3.685714    6
# 3          1      4 2019-01-07     0.0         0.0  0.693107  3.695714    0
# 4          1      4 2019-01-08     0.0         0.0  0.787740  3.722857    1
# ...      ...    ...        ...     ...         ...       ...       ...  ...
# 108995   100      2 2021-12-24     0.0         0.0  1.390103  4.771429    4
# 108996   100      2 2021-12-25     0.0         0.0  1.389816  4.792857    5
# 108997   100      2 2021-12-26     0.0         0.0  0.669045  4.752857    6
# 108998   100      2 2021-12-27     0.0         0.0  0.693107  4.610000    0
# 108999   100      2 2021-12-28     0.0         0.0  0.787740  4.537143    1
#
#         doy
# 0         4
# 1         5
# 2         6
# 3         7
# 4         8
# ...     ...
# 108995  358
# 108996  359
# 108997  360
# 108998  361
# 108999  362
#
# [109000 rows x 9 columns]

# %% [markdown]
# Build the sequence data.

# %%
window = 29
future_span = 30
series = series_to_supervised(df_train.drop('date', axis=1), window=window, lag=future_span)
series.head()
# Out:
#     item(t-29)  store(t-29)  adjust(t-29)  item_count(t-29)  seasonal(t-29)  \
# 29         1.0          4.0           0.0               0.0        1.390103
# 30         1.0          4.0           0.0               0.0        1.389816
# 31         1.0          4.0           0.0               0.0        0.669045
# 32         1.0          4.0           0.0               0.0        0.693107
# 33         1.0          4.0           0.0               0.0        0.787740
#
#     trend(t-29)  dow(t-29)  doy(t-29)  item(t-28)  store(t-28)  ...  dow(t)  \
# 29     3.920000        4.0        4.0         1.0          4.0  ...       5
# 30     3.672857        5.0        5.0         1.0          4.0  ...       6
# 31     3.685714        6.0        6.0         1.0          4.0  ...       0
# 32     3.695714        0.0        7.0         1.0          4.0  ...       1
# 33     3.722857        1.0        8.0         1.0          4.0  ...       2
#
#     doy(t)  item(t+30)  store(t+30)  adjust(t+30)  item_count(t+30)  \
# 29      33         1.0          4.0           0.0               0.0
# 30      34         1.0          4.0           0.0               0.0
# 31      35         1.0          4.0           0.0               0.0
# 32      36         1.0          4.0           0.0               0.0
# 33      37         1.0          4.0           0.0               0.0
#
#     seasonal(t+30)  trend(t+30)  dow(t+30)  doy(t+30)
# 29        0.693107     4.892857        0.0       63.0
# 30        0.787740     4.971429        1.0       64.0
# 31        0.884056     5.044286        2.0       65.0
# 32        1.186132     5.117143        3.0       66.0
# 33        1.390103     5.184286        4.0       67.0
#
# [5 rows x 248 columns]

# %% [markdown]
# Remove sequences that did not have enough data.

# %%
# Remove edge cases, where there were not enough values to complete a series
last_item = 'item(t-%d)' % window
last_store = 'store(t-%d)' % window
last_dow = 'dow(t-%d)' % window
last_doy = 'doy(t-%d)' % window
series = series[(series['store(t)'] == series[last_store])]
series = series[(series['item(t)'] == series[last_item])]

# %% [markdown]
# We will predict with adjusted sales, and our engineered features.

# %%
import numpy as np
from keras.utils.np_utils import to_categorical   

def drop_column(df, col):
  columns_to_drop = [('%s(t+%d)' % (col, future_span))]
  for i in range(window, 0, -1):
      columns_to_drop += [('%s(t-%d)' % (col, i))]
  df.drop(columns_to_drop, axis=1, inplace=True, errors='ignore')
  df.drop([f"{col}(t)"], axis=1, inplace=True, errors='ignore')

def cat_seq(df, col):
  return to_categorical(df[col].values)

# Label
labels_col = 'adjust(t+%d)' % future_span
labels = series[labels_col]
series.drop(labels_col, axis=1, inplace=True)
series.drop('item(t+%d)' % future_span, axis=1, inplace=True)
series.drop('store(t+%d)' % future_span, axis=1, inplace=True)
series.drop('dow(t+%d)' % future_span, axis=1, inplace=True)
series.drop('doy(t+%d)' % future_span, axis=1, inplace=True)

# Adjustment columns
unadjust_sales_col = 'item_count(t+%d)' % future_span
seasonal_col = 'seasonal(t+%d)' % future_span
trend_col = 'trend(t+%d)' % future_span

hold_sales = series[unadjust_sales_col]
hold_seasonal = series[seasonal_col]
hold_trend = series[trend_col]

series.drop(unadjust_sales_col, axis=1, inplace=True)
series.drop(seasonal_col, axis=1, inplace=True)
series.drop(trend_col, axis=1, inplace=True)


# Get sales sequences
series2 = series.copy()
drop_column(series2, "item")
drop_column(series2, "store")
drop_column(series2, "dow")
drop_column(series2, "doy")
sales_series = series2.values

# Day of week as a categorical
series2 = series.copy()
drop_column(series2, "item")
drop_column(series2, "store")
drop_column(series2, "doy")
drop_column(series2, "adjust")
dow_series = series2.values

# Get item sequences
series2 = series.copy()
drop_column(series2, "item")
drop_column(series2, "store")
drop_column(series2, "dow")
drop_column(series2, "adjust")
doy_series = series2.values

# Day of year
t1 = sales_series.reshape(sales_series.shape + (1,))
t2 = dow_series.reshape(dow_series.shape + (1,)) 
t3 = doy_series.reshape(doy_series.shape + (1,))
x = np.concatenate([t1,t2,t3],axis=2)

# %% [markdown]
# Double check that all input data is of the same shape.

# %%
print(t1.shape)
print(t2.shape)
print(t3.shape)
# Out:
# (106070, 120, 1)
# (106070, 120, 1)
# (106070, 120, 1)

# %% [markdown]
# Extract the predictors (x sequences) and the label (future prediction)

# %%
from sklearn.model_selection import train_test_split

# Split the training data into training and validation
data = np.arange(len(x))
y = labels.values
np.random.shuffle(data)
split_pt = int(len(data) * 0.2)
x_valid = x[data[:split_pt]]
x_train = x[data[split_pt:]]
y_valid = y[data[:split_pt]]
y_train = y[data[split_pt:]]

# Also split the seasonality/trend data
y_train_actual = hold_sales.iloc[data[split_pt:]]
y_valid_actual = hold_sales.iloc[data[:split_pt]]

y_train_seasonal = hold_seasonal.iloc[data[split_pt:]]
y_valid_seasonal = hold_seasonal.iloc[data[:split_pt]]

y_train_trend = hold_trend.iloc[data[split_pt:]]
y_valid_trend = hold_trend.iloc[data[:split_pt]]

# Display results
print('Train set shape', x_train.shape)
print('Validation set shape', x_valid.shape)
# Out:
# Train set shape (84856, 120, 3)
# Validation set shape (21214, 120, 3)

# %% [markdown]
# Final preparation for the x and y.

# %%
print('Train set shape', x_train.shape)
print('Validation set shape', y_valid.shape)
# Out:
# Train set shape (84856, 120, 3)
# Validation set shape (21214,)

# %% [markdown]
# Construct the neural network.

# %%
import tensorflow as tf 
from keras.models import Sequential, Model
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers import Dense, LSTM, RepeatVector, TimeDistributed, Flatten, Dropout
import keras

epochs = 500
batch = 256
lr = 0.0003
adam = tf.keras.optimizers.Adam(lr)

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=8, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mse', optimizer=adam)
model.summary()

#model = Sequential()
#model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
#model.add(Dense(1))
#model.compile(loss='mse', optimizer=adam)
#model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 113, 64)           1600
#
#  max_pooling1d (MaxPooling1D  (None, 56, 64)           0
#  )
#
#  flatten (Flatten)           (None, 3584)              0
#
#  dense (Dense)               (None, 50)                179250
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 180,901
# Trainable params: 180,901
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Fit the neural network.

# %%
from keras.callbacks import EarlyStopping

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=50, 
        verbose=1, mode='auto', restore_best_weights=True)

cnn_history = model.fit(x_train, y_train, callbacks=[monitor],
    validation_data=(x_valid, y_valid), epochs=epochs, verbose=2)
# Out:
# Epoch 1/500
# 2652/2652 - 27s - loss: 8.3706 - val_loss: 2.5606 - 27s/epoch - 10ms/step
# Epoch 2/500
# 2652/2652 - 23s - loss: 4.1796 - val_loss: 2.1215 - 23s/epoch - 9ms/step
# Epoch 3/500
# 2652/2652 - 23s - loss: 3.7689 - val_loss: 2.7292 - 23s/epoch - 9ms/step
# Epoch 4/500
# 2652/2652 - 24s - loss: 3.7217 - val_loss: 1.9440 - 24s/epoch - 9ms/step
# Epoch 5/500
# 2652/2652 - 24s - loss: 3.7130 - val_loss: 2.3287 - 24s/epoch - 9ms/step
# Epoch 6/500
# 2652/2652 - 23s - loss: 3.3905 - val_loss: 2.4259 - 23s/epoch - 9ms/step
# Epoch 7/500
# 2652/2652 - 23s - loss: 3.1674 - val_loss: 2.8802 - 23s/epoch - 9ms/step
# Epoch 8/500
# 2652/2652 - 24s - loss: 3.1927 - val_loss: 2.1591 - 24s/epoch - 9ms/step
# Epoch 9/500
# 2652/2652 - 24s - loss: 2.9378 - val_loss: 2.1832 - 24s/epoch - 9ms/step
# Epoch 10/500
# 2652/2652 - 24s - loss: 2.8227 - val_loss: 2.0287 - 24s/epoch - 9ms/step
# Epoch 11/500
# 2652/2652 - 24s - loss: 3.0116 - val_loss: 1.9584 - 24s/epoch - 9ms/step
# Epoch 12/500
# 2652/2652 - 24s - loss: 2.8182 - val_loss: 2.0102 - 24s/epoch - 9ms/step
# Epoch 13/500
# 2652/2652 - 25s - loss: 2.7422 - val_loss: 1.8195 - 25s/epoch - 9ms/step
# Epoch 14/500
# 2652/2652 - 23s - loss: 2.9424 - val_loss: 1.8379 - 23s/epoch - 9ms/step
# Epoch 15/500
# 2652/2652 - 24s - loss: 2.8357 - val_loss: 2.0059 - 24s/epoch - 9ms/step
# Epoch 16/500
# 2652/2652 - 24s - loss: 2.6449 - val_loss: 2.1214 - 24s/epoch - 9ms/step
# Epoch 17/500
# 2652/2652 - 23s - loss: 2.5983 - val_loss: 2.2520 - 23s/epoch - 9ms/step
# Epoch 18/500
# 2652/2652 - 24s - loss: 2.6006 - val_loss: 1.7560 - 24s/epoch - 9ms/step
# Epoch 19/500
# 2652/2652 - 23s - loss: 2.6235 - val_loss: 1.8086 - 23s/epoch - 9ms/step
# Epoch 20/500
# 2652/2652 - 24s - loss: 2.6017 - val_loss: 1.8089 - 24s/epoch - 9ms/step
# Epoch 21/500
# 2652/2652 - 24s - loss: 2.6322 - val_loss: 2.0068 - 24s/epoch - 9ms/step
# Epoch 22/500
# 2652/2652 - 25s - loss: 2.5958 - val_loss: 2.1085 - 25s/epoch - 9ms/step
# Epoch 23/500
# 2652/2652 - 23s - loss: 2.4442 - val_loss: 1.8557 - 23s/epoch - 9ms/step
# Epoch 24/500
# 2652/2652 - 23s - loss: 2.4873 - val_loss: 2.3639 - 23s/epoch - 9ms/step
# Epoch 25/500
# 2652/2652 - 23s - loss: 2.4360 - val_loss: 1.7957 - 23s/epoch - 9ms/step
# Epoch 26/500
# 2652/2652 - 23s - loss: 2.4461 - val_loss: 1.8407 - 23s/epoch - 9ms/step
# Epoch 27/500
# 2652/2652 - 23s - loss: 2.4650 - val_loss: 1.9666 - 23s/epoch - 9ms/step
# Epoch 28/500
# 2652/2652 - 23s - loss: 2.3712 - val_loss: 1.7284 - 23s/epoch - 9ms/step
# Epoch 29/500
# 2652/2652 - 23s - loss: 2.4865 - val_loss: 2.1414 - 23s/epoch - 9ms/step
# Epoch 30/500
# 2652/2652 - 23s - loss: 2.4147 - val_loss: 1.7979 - 23s/epoch - 9ms/step
# Epoch 31/500
# 2652/2652 - 23s - loss: 2.4385 - val_loss: 1.7750 - 23s/epoch - 9ms/step
# Epoch 32/500
# 2652/2652 - 25s - loss: 2.4273 - val_loss: 2.2538 - 25s/epoch - 9ms/step
# Epoch 33/500
# 2652/2652 - 23s - loss: 2.3762 - val_loss: 1.7705 - 23s/epoch - 9ms/step
# Epoch 34/500
# 2652/2652 - 24s - loss: 2.3607 - val_loss: 1.7277 - 24s/epoch - 9ms/step
# Epoch 35/500
# 2652/2652 - 23s - loss: 2.2874 - val_loss: 1.7234 - 23s/epoch - 9ms/step
# Epoch 36/500
# 2652/2652 - 24s - loss: 2.4053 - val_loss: 1.7033 - 24s/epoch - 9ms/step
# Epoch 37/500
# 2652/2652 - 23s - loss: 2.3618 - val_loss: 1.8055 - 23s/epoch - 9ms/step
# Epoch 38/500
# 2652/2652 - 23s - loss: 2.4058 - val_loss: 1.7869 - 23s/epoch - 9ms/step
# Epoch 39/500
# 2652/2652 - 23s - loss: 2.3120 - val_loss: 1.9181 - 23s/epoch - 9ms/step
# Epoch 40/500
# 2652/2652 - 23s - loss: 2.2992 - val_loss: 1.8513 - 23s/epoch - 9ms/step
# Epoch 41/500
# 2652/2652 - 25s - loss: 2.2769 - val_loss: 1.6941 - 25s/epoch - 9ms/step
# Epoch 42/500
# 2652/2652 - 23s - loss: 2.3327 - val_loss: 1.8433 - 23s/epoch - 9ms/step
# Epoch 43/500
# 2652/2652 - 23s - loss: 2.3492 - val_loss: 1.7727 - 23s/epoch - 9ms/step
# Epoch 44/500
# 2652/2652 - 23s - loss: 2.3081 - val_loss: 1.7050 - 23s/epoch - 9ms/step
# Epoch 45/500
# 2652/2652 - 23s - loss: 2.3026 - val_loss: 1.9544 - 23s/epoch - 9ms/step
# Epoch 46/500
# 2652/2652 - 23s - loss: 2.2577 - val_loss: 1.7334 - 23s/epoch - 9ms/step
# Epoch 47/500
# 2652/2652 - 23s - loss: 2.2560 - val_loss: 1.9851 - 23s/epoch - 9ms/step
# Epoch 48/500
# 2652/2652 - 24s - loss: 2.3066 - val_loss: 1.7692 - 24s/epoch - 9ms/step
# Epoch 49/500
# 2652/2652 - 23s - loss: 2.2242 - val_loss: 1.9137 - 23s/epoch - 9ms/step
# Epoch 50/500
# 2652/2652 - 23s - loss: 2.1809 - val_loss: 1.7414 - 23s/epoch - 9ms/step
# Epoch 51/500
# 2652/2652 - 25s - loss: 2.2367 - val_loss: 1.7772 - 25s/epoch - 9ms/step
# Epoch 52/500
# 2652/2652 - 23s - loss: 2.2394 - val_loss: 1.8001 - 23s/epoch - 9ms/step
# Epoch 53/500
# 2652/2652 - 23s - loss: 2.2530 - val_loss: 1.7847 - 23s/epoch - 9ms/step
# Epoch 54/500
# 2652/2652 - 23s - loss: 2.1574 - val_loss: 1.7382 - 23s/epoch - 9ms/step
# Epoch 55/500
# 2652/2652 - 23s - loss: 2.2772 - val_loss: 1.7028 - 23s/epoch - 9ms/step
# Epoch 56/500
# 2652/2652 - 23s - loss: 2.2310 - val_loss: 1.8343 - 23s/epoch - 9ms/step
# Epoch 57/500
# 2652/2652 - 23s - loss: 2.2660 - val_loss: 1.7096 - 23s/epoch - 9ms/step
# Epoch 58/500
# 2652/2652 - 22s - loss: 2.1798 - val_loss: 1.8257 - 22s/epoch - 8ms/step
# Epoch 59/500
# 2652/2652 - 23s - loss: 2.2342 - val_loss: 1.6927 - 23s/epoch - 9ms/step
# Epoch 60/500
# 2652/2652 - 23s - loss: 2.2102 - val_loss: 1.7685 - 23s/epoch - 9ms/step
# Epoch 61/500
# 2652/2652 - 25s - loss: 2.1973 - val_loss: 1.7533 - 25s/epoch - 10ms/step
# Epoch 62/500
# 2652/2652 - 23s - loss: 2.1715 - val_loss: 1.6632 - 23s/epoch - 9ms/step
# Epoch 63/500
# 2652/2652 - 23s - loss: 2.1323 - val_loss: 1.6965 - 23s/epoch - 9ms/step
# Epoch 64/500
# 2652/2652 - 23s - loss: 2.2071 - val_loss: 1.7091 - 23s/epoch - 9ms/step
# Epoch 65/500
# 2652/2652 - 23s - loss: 2.1356 - val_loss: 1.7508 - 23s/epoch - 9ms/step
# Epoch 66/500
# 2652/2652 - 23s - loss: 2.2105 - val_loss: 1.7504 - 23s/epoch - 9ms/step
# Epoch 67/500
# 2652/2652 - 35s - loss: 2.1782 - val_loss: 1.6815 - 35s/epoch - 13ms/step
# Epoch 68/500
# 2652/2652 - 23s - loss: 2.1950 - val_loss: 2.1122 - 23s/epoch - 9ms/step
# Epoch 69/500
# 2652/2652 - 23s - loss: 2.1547 - val_loss: 1.6666 - 23s/epoch - 9ms/step
# Epoch 70/500
# 2652/2652 - 25s - loss: 2.2017 - val_loss: 1.9166 - 25s/epoch - 9ms/step
# Epoch 71/500
# 2652/2652 - 25s - loss: 2.1893 - val_loss: 2.2081 - 25s/epoch - 9ms/step
# Epoch 72/500
# 2652/2652 - 23s - loss: 2.0474 - val_loss: 1.7326 - 23s/epoch - 9ms/step
# Epoch 73/500
# 2652/2652 - 23s - loss: 2.0185 - val_loss: 1.9714 - 23s/epoch - 9ms/step
# Epoch 74/500
# 2652/2652 - 24s - loss: 2.0492 - val_loss: 1.7174 - 24s/epoch - 9ms/step
# Epoch 75/500
# 2652/2652 - 23s - loss: 2.1351 - val_loss: 1.8278 - 23s/epoch - 9ms/step
# Epoch 76/500
# 2652/2652 - 23s - loss: 2.0061 - val_loss: 1.6947 - 23s/epoch - 9ms/step
# Epoch 77/500
# 2652/2652 - 24s - loss: 2.0679 - val_loss: 1.8087 - 24s/epoch - 9ms/step
# Epoch 78/500
# 2652/2652 - 24s - loss: 2.0345 - val_loss: 1.7139 - 24s/epoch - 9ms/step
# Epoch 79/500
# 2652/2652 - 24s - loss: 1.9993 - val_loss: 1.7066 - 24s/epoch - 9ms/step
# Epoch 80/500
# 2652/2652 - 24s - loss: 2.0743 - val_loss: 1.7744 - 24s/epoch - 9ms/step
# Epoch 81/500
# 2652/2652 - 24s - loss: 1.9872 - val_loss: 1.5965 - 24s/epoch - 9ms/step
# Epoch 82/500
# 2652/2652 - 24s - loss: 2.0173 - val_loss: 1.6031 - 24s/epoch - 9ms/step
# Epoch 83/500
# 2652/2652 - 23s - loss: 2.0072 - val_loss: 1.8638 - 23s/epoch - 9ms/step
# Epoch 84/500
# 2652/2652 - 23s - loss: 2.0185 - val_loss: 1.6520 - 23s/epoch - 9ms/step
# Epoch 85/500
# 2652/2652 - 23s - loss: 1.9485 - val_loss: 1.9331 - 23s/epoch - 9ms/step
# Epoch 86/500
# 2652/2652 - 23s - loss: 2.0013 - val_loss: 1.6015 - 23s/epoch - 9ms/step
# Epoch 87/500
# 2652/2652 - 23s - loss: 2.0219 - val_loss: 1.5913 - 23s/epoch - 9ms/step
# Epoch 88/500
# 2652/2652 - 24s - loss: 1.9543 - val_loss: 1.8335 - 24s/epoch - 9ms/step
# Epoch 89/500
# 2652/2652 - 25s - loss: 1.9828 - val_loss: 1.6033 - 25s/epoch - 9ms/step
# Epoch 90/500
# 2652/2652 - 23s - loss: 1.9245 - val_loss: 1.6189 - 23s/epoch - 9ms/step
# Epoch 91/500
# 2652/2652 - 23s - loss: 1.9454 - val_loss: 1.8291 - 23s/epoch - 9ms/step
# Epoch 92/500
# 2652/2652 - 23s - loss: 1.9558 - val_loss: 1.6031 - 23s/epoch - 9ms/step
# Epoch 93/500
# 2652/2652 - 24s - loss: 1.9153 - val_loss: 1.6162 - 24s/epoch - 9ms/step
# Epoch 94/500
# 2652/2652 - 23s - loss: 1.9088 - val_loss: 1.6660 - 23s/epoch - 9ms/step
# Epoch 95/500
# 2652/2652 - 23s - loss: 1.9748 - val_loss: 1.6411 - 23s/epoch - 9ms/step
# Epoch 96/500
# 2652/2652 - 23s - loss: 1.8608 - val_loss: 1.7567 - 23s/epoch - 9ms/step
# Epoch 97/500
# 2652/2652 - 23s - loss: 1.9884 - val_loss: 1.6299 - 23s/epoch - 9ms/step
# Epoch 98/500
# 2652/2652 - 23s - loss: 1.9738 - val_loss: 1.6290 - 23s/epoch - 8ms/step
# Epoch 99/500
# 2652/2652 - 24s - loss: 1.8579 - val_loss: 1.5976 - 24s/epoch - 9ms/step
# Epoch 100/500
# 2652/2652 - 23s - loss: 1.8613 - val_loss: 1.5906 - 23s/epoch - 9ms/step
# Epoch 101/500
# 2652/2652 - 23s - loss: 1.8910 - val_loss: 1.6371 - 23s/epoch - 9ms/step
# Epoch 102/500
# 2652/2652 - 23s - loss: 1.9159 - val_loss: 1.6552 - 23s/epoch - 9ms/step
# Epoch 103/500
# 2652/2652 - 24s - loss: 1.8977 - val_loss: 1.6668 - 24s/epoch - 9ms/step
# Epoch 104/500
# 2652/2652 - 23s - loss: 1.8212 - val_loss: 1.7335 - 23s/epoch - 9ms/step
# Epoch 105/500
# 2652/2652 - 23s - loss: 1.9083 - val_loss: 1.5497 - 23s/epoch - 9ms/step
# Epoch 106/500
# 2652/2652 - 23s - loss: 1.8678 - val_loss: 2.1909 - 23s/epoch - 9ms/step
# Epoch 107/500
# 2652/2652 - 24s - loss: 1.8706 - val_loss: 1.5819 - 24s/epoch - 9ms/step
# Epoch 108/500
# 2652/2652 - 23s - loss: 1.8228 - val_loss: 1.6634 - 23s/epoch - 9ms/step
# Epoch 109/500
# 2652/2652 - 25s - loss: 1.8467 - val_loss: 2.1076 - 25s/epoch - 9ms/step
# Epoch 110/500
# 2652/2652 - 23s - loss: 1.8408 - val_loss: 1.6005 - 23s/epoch - 9ms/step
# Epoch 111/500
# 2652/2652 - 23s - loss: 1.8426 - val_loss: 1.6408 - 23s/epoch - 9ms/step
# Epoch 112/500
# 2652/2652 - 24s - loss: 1.8372 - val_loss: 1.8741 - 24s/epoch - 9ms/step
# Epoch 113/500
# 2652/2652 - 23s - loss: 1.8163 - val_loss: 1.6518 - 23s/epoch - 9ms/step
# Epoch 114/500
# 2652/2652 - 23s - loss: 1.8425 - val_loss: 1.5891 - 23s/epoch - 9ms/step
# Epoch 115/500
# 2652/2652 - 23s - loss: 1.8274 - val_loss: 1.6471 - 23s/epoch - 9ms/step
# Epoch 116/500
# 2652/2652 - 24s - loss: 1.8905 - val_loss: 1.7255 - 24s/epoch - 9ms/step
# Epoch 117/500
# 2652/2652 - 23s - loss: 1.8139 - val_loss: 1.5795 - 23s/epoch - 9ms/step
# Epoch 118/500
# 2652/2652 - 23s - loss: 1.8563 - val_loss: 1.9556 - 23s/epoch - 9ms/step
# Epoch 119/500
# 2652/2652 - 24s - loss: 1.8488 - val_loss: 2.2224 - 24s/epoch - 9ms/step
# Epoch 120/500
# 2652/2652 - 23s - loss: 1.8091 - val_loss: 1.5489 - 23s/epoch - 9ms/step
# Epoch 121/500
# 2652/2652 - 23s - loss: 1.8085 - val_loss: 1.5892 - 23s/epoch - 9ms/step
# Epoch 122/500
# 2652/2652 - 23s - loss: 1.7708 - val_loss: 1.5833 - 23s/epoch - 9ms/step
# Epoch 123/500
# 2652/2652 - 23s - loss: 1.8253 - val_loss: 1.5513 - 23s/epoch - 9ms/step
# Epoch 124/500
# 2652/2652 - 23s - loss: 1.8579 - val_loss: 1.7128 - 23s/epoch - 9ms/step
# Epoch 125/500
# 2652/2652 - 23s - loss: 1.8178 - val_loss: 1.6235 - 23s/epoch - 9ms/step
# Epoch 126/500
# 2652/2652 - 23s - loss: 1.8040 - val_loss: 1.5933 - 23s/epoch - 9ms/step
# Epoch 127/500
# 2652/2652 - 23s - loss: 1.8018 - val_loss: 1.6271 - 23s/epoch - 9ms/step
# Epoch 128/500
# 2652/2652 - 24s - loss: 1.8063 - val_loss: 1.5622 - 24s/epoch - 9ms/step
# Epoch 129/500
# 2652/2652 - 23s - loss: 1.8359 - val_loss: 1.6752 - 23s/epoch - 9ms/step
# Epoch 130/500
# 2652/2652 - 25s - loss: 1.7855 - val_loss: 1.6093 - 25s/epoch - 9ms/step
# Epoch 131/500
# 2652/2652 - 23s - loss: 1.7851 - val_loss: 1.5852 - 23s/epoch - 9ms/step
# Epoch 132/500
# 2652/2652 - 23s - loss: 1.7804 - val_loss: 1.6762 - 23s/epoch - 9ms/step
# Epoch 133/500
# 2652/2652 - 23s - loss: 1.7825 - val_loss: 1.7847 - 23s/epoch - 9ms/step
# Epoch 134/500
# 2652/2652 - 23s - loss: 1.7733 - val_loss: 1.6205 - 23s/epoch - 9ms/step
# Epoch 135/500
# 2652/2652 - 23s - loss: 1.7120 - val_loss: 1.5470 - 23s/epoch - 9ms/step
# Epoch 136/500
# 2652/2652 - 23s - loss: 1.7402 - val_loss: 1.8977 - 23s/epoch - 9ms/step
# Epoch 137/500
# 2652/2652 - 23s - loss: 1.7641 - val_loss: 1.6429 - 23s/epoch - 9ms/step
# Epoch 138/500
# 2652/2652 - 23s - loss: 1.7982 - val_loss: 1.6201 - 23s/epoch - 9ms/step
# Epoch 139/500
# 2652/2652 - 23s - loss: 1.7522 - val_loss: 1.5744 - 23s/epoch - 9ms/step
# Epoch 140/500
# 2652/2652 - 25s - loss: 1.8342 - val_loss: 1.6971 - 25s/epoch - 9ms/step
# Epoch 141/500
# 2652/2652 - 23s - loss: 1.7516 - val_loss: 1.7031 - 23s/epoch - 9ms/step
# Epoch 142/500
# 2652/2652 - 23s - loss: 1.7656 - val_loss: 1.5865 - 23s/epoch - 9ms/step
# Epoch 143/500
# 2652/2652 - 23s - loss: 1.7352 - val_loss: 1.5894 - 23s/epoch - 9ms/step
# Epoch 144/500
# 2652/2652 - 23s - loss: 1.7691 - val_loss: 1.9606 - 23s/epoch - 9ms/step
# Epoch 145/500
# 2652/2652 - 23s - loss: 1.8333 - val_loss: 1.5705 - 23s/epoch - 9ms/step
# Epoch 146/500
# 2652/2652 - 24s - loss: 1.6989 - val_loss: 1.5356 - 24s/epoch - 9ms/step
# Epoch 147/500
# 2652/2652 - 23s - loss: 1.7365 - val_loss: 1.6208 - 23s/epoch - 9ms/step
# Epoch 148/500
# 2652/2652 - 23s - loss: 1.7813 - val_loss: 1.5707 - 23s/epoch - 9ms/step
# Epoch 149/500
# 2652/2652 - 23s - loss: 1.6863 - val_loss: 1.7245 - 23s/epoch - 9ms/step
# Epoch 150/500
# 2652/2652 - 25s - loss: 1.7705 - val_loss: 1.6155 - 25s/epoch - 9ms/step
# Epoch 151/500
# 2652/2652 - 23s - loss: 1.7390 - val_loss: 1.6660 - 23s/epoch - 9ms/step
# Epoch 152/500
# 2652/2652 - 23s - loss: 1.7134 - val_loss: 1.7595 - 23s/epoch - 9ms/step
# Epoch 153/500
# 2652/2652 - 23s - loss: 1.8151 - val_loss: 1.6292 - 23s/epoch - 9ms/step
# Epoch 154/500
# 2652/2652 - 23s - loss: 1.7167 - val_loss: 1.6739 - 23s/epoch - 9ms/step
# Epoch 155/500
# 2652/2652 - 23s - loss: 1.7240 - val_loss: 1.5650 - 23s/epoch - 9ms/step
# Epoch 156/500
# 2652/2652 - 23s - loss: 1.7106 - val_loss: 1.5796 - 23s/epoch - 9ms/step
# Epoch 157/500
# 2652/2652 - 24s - loss: 1.7820 - val_loss: 1.5874 - 24s/epoch - 9ms/step
# Epoch 158/500
# 2652/2652 - 23s - loss: 1.7327 - val_loss: 1.5759 - 23s/epoch - 9ms/step
# Epoch 159/500
# 2652/2652 - 23s - loss: 1.7140 - val_loss: 1.5800 - 23s/epoch - 9ms/step
# Epoch 160/500
# 2652/2652 - 25s - loss: 1.7389 - val_loss: 2.3238 - 25s/epoch - 9ms/step
# Epoch 161/500
# 2652/2652 - 23s - loss: 1.7167 - val_loss: 1.7942 - 23s/epoch - 9ms/step
# Epoch 162/500
# 2652/2652 - 23s - loss: 1.7406 - val_loss: 1.6464 - 23s/epoch - 9ms/step
# Epoch 163/500
# 2652/2652 - 23s - loss: 1.6829 - val_loss: 1.5519 - 23s/epoch - 9ms/step
# Epoch 164/500
# 2652/2652 - 24s - loss: 1.7087 - val_loss: 1.7198 - 24s/epoch - 9ms/step
# Epoch 165/500
# 2652/2652 - 23s - loss: 1.7245 - val_loss: 1.7262 - 23s/epoch - 9ms/step
# Epoch 166/500
# 2652/2652 - 23s - loss: 1.8024 - val_loss: 1.5436 - 23s/epoch - 9ms/step
# Epoch 167/500
# 2652/2652 - 23s - loss: 1.7432 - val_loss: 1.7231 - 23s/epoch - 9ms/step
# Epoch 168/500
# 2652/2652 - 23s - loss: 1.7314 - val_loss: 1.6521 - 23s/epoch - 9ms/step
# Epoch 169/500
# 2652/2652 - 24s - loss: 1.7586 - val_loss: 1.5815 - 24s/epoch - 9ms/step
# Epoch 170/500
# 2652/2652 - 25s - loss: 1.6872 - val_loss: 1.5514 - 25s/epoch - 10ms/step
# Epoch 171/500
# 2652/2652 - 23s - loss: 1.7453 - val_loss: 1.8015 - 23s/epoch - 9ms/step
# Epoch 172/500
# 2652/2652 - 23s - loss: 1.7863 - val_loss: 1.5577 - 23s/epoch - 9ms/step
# Epoch 173/500
# 2652/2652 - 24s - loss: 1.6615 - val_loss: 1.6412 - 24s/epoch - 9ms/step
# Epoch 174/500
# 2652/2652 - 23s - loss: 1.7025 - val_loss: 1.5004 - 23s/epoch - 9ms/step
# Epoch 175/500
# 2652/2652 - 23s - loss: 1.6696 - val_loss: 1.5179 - 23s/epoch - 9ms/step
# Epoch 176/500
# 2652/2652 - 23s - loss: 1.7621 - val_loss: 1.6713 - 23s/epoch - 9ms/step
# Epoch 177/500
# 2652/2652 - 23s - loss: 1.6994 - val_loss: 1.6145 - 23s/epoch - 9ms/step
# Epoch 178/500
# 2652/2652 - 23s - loss: 1.7693 - val_loss: 1.5881 - 23s/epoch - 9ms/step
# Epoch 179/500
# 2652/2652 - 24s - loss: 1.7398 - val_loss: 1.6076 - 24s/epoch - 9ms/step
# Epoch 180/500
# 2652/2652 - 26s - loss: 1.7270 - val_loss: 1.6130 - 26s/epoch - 10ms/step
# Epoch 181/500
# 2652/2652 - 23s - loss: 1.6773 - val_loss: 1.5246 - 23s/epoch - 9ms/step
# Epoch 182/500
# 2652/2652 - 23s - loss: 1.7681 - val_loss: 1.6828 - 23s/epoch - 9ms/step
# Epoch 183/500
# 2652/2652 - 23s - loss: 1.7628 - val_loss: 1.6529 - 23s/epoch - 9ms/step
# Epoch 184/500
# 2652/2652 - 24s - loss: 1.7038 - val_loss: 1.6001 - 24s/epoch - 9ms/step
# Epoch 185/500
# 2652/2652 - 23s - loss: 1.6516 - val_loss: 1.6062 - 23s/epoch - 9ms/step
# Epoch 186/500
# 2652/2652 - 23s - loss: 1.7243 - val_loss: 1.5800 - 23s/epoch - 9ms/step
# Epoch 187/500
# 2652/2652 - 23s - loss: 1.7534 - val_loss: 1.6943 - 23s/epoch - 9ms/step
# Epoch 188/500
# 2652/2652 - 23s - loss: 1.6826 - val_loss: 1.5840 - 23s/epoch - 9ms/step
# Epoch 189/500
# 2652/2652 - 23s - loss: 1.7182 - val_loss: 1.7260 - 23s/epoch - 9ms/step
# Epoch 190/500
# 2652/2652 - 23s - loss: 1.7416 - val_loss: 1.7787 - 23s/epoch - 9ms/step
# Epoch 191/500
# 2652/2652 - 25s - loss: 1.6869 - val_loss: 1.6181 - 25s/epoch - 9ms/step
# Epoch 192/500
# 2652/2652 - 23s - loss: 1.7494 - val_loss: 1.6915 - 23s/epoch - 9ms/step
# Epoch 193/500
# 2652/2652 - 24s - loss: 1.6963 - val_loss: 1.5872 - 24s/epoch - 9ms/step
# Epoch 194/500
# 2652/2652 - 23s - loss: 1.7065 - val_loss: 1.5820 - 23s/epoch - 9ms/step
# Epoch 195/500
# 2652/2652 - 24s - loss: 1.6836 - val_loss: 1.6251 - 24s/epoch - 9ms/step
# Epoch 196/500
# 2652/2652 - 23s - loss: 1.7141 - val_loss: 1.9943 - 23s/epoch - 9ms/step
# Epoch 197/500
# 2652/2652 - 23s - loss: 1.7031 - val_loss: 1.5833 - 23s/epoch - 9ms/step
# Epoch 198/500
# 2652/2652 - 24s - loss: 1.7057 - val_loss: 1.6782 - 24s/epoch - 9ms/step
# Epoch 199/500
# 2652/2652 - 24s - loss: 1.6966 - val_loss: 1.6513 - 24s/epoch - 9ms/step
# Epoch 200/500
# 2652/2652 - 23s - loss: 1.7463 - val_loss: 2.4520 - 23s/epoch - 9ms/step
# Epoch 201/500
# 2652/2652 - 24s - loss: 1.7153 - val_loss: 1.5972 - 24s/epoch - 9ms/step
# Epoch 202/500
# 2652/2652 - 23s - loss: 1.6796 - val_loss: 1.8548 - 23s/epoch - 9ms/step
# Epoch 203/500
# 2652/2652 - 23s - loss: 1.7010 - val_loss: 1.9269 - 23s/epoch - 9ms/step
# Epoch 204/500
# 2652/2652 - 23s - loss: 1.6378 - val_loss: 1.6103 - 23s/epoch - 9ms/step
# Epoch 205/500
# 2652/2652 - 24s - loss: 1.6687 - val_loss: 1.7423 - 24s/epoch - 9ms/step
# Epoch 206/500
# 2652/2652 - 23s - loss: 1.6870 - val_loss: 1.5532 - 23s/epoch - 9ms/step
# Epoch 207/500
# 2652/2652 - 23s - loss: 1.6976 - val_loss: 1.5364 - 23s/epoch - 9ms/step
# Epoch 208/500
# 2652/2652 - 23s - loss: 1.6639 - val_loss: 1.5033 - 23s/epoch - 9ms/step
# Epoch 209/500
# 2652/2652 - 23s - loss: 1.6817 - val_loss: 1.5170 - 23s/epoch - 9ms/step
# Epoch 210/500
# 2652/2652 - 24s - loss: 1.6955 - val_loss: 1.8905 - 24s/epoch - 9ms/step
# Epoch 211/500
# 2652/2652 - 25s - loss: 1.6847 - val_loss: 1.5875 - 25s/epoch - 9ms/step
# Epoch 212/500
# 2652/2652 - 24s - loss: 1.6795 - val_loss: 1.5415 - 24s/epoch - 9ms/step
# Epoch 213/500
# 2652/2652 - 23s - loss: 1.7255 - val_loss: 1.7305 - 23s/epoch - 9ms/step
# Epoch 214/500
# 2652/2652 - 24s - loss: 1.6475 - val_loss: 2.0501 - 24s/epoch - 9ms/step
# Epoch 215/500
# 2652/2652 - 24s - loss: 1.6919 - val_loss: 1.6807 - 24s/epoch - 9ms/step
# Epoch 216/500
# 2652/2652 - 23s - loss: 1.6888 - val_loss: 1.6006 - 23s/epoch - 9ms/step
# Epoch 217/500
# 2652/2652 - 23s - loss: 1.6995 - val_loss: 1.5320 - 23s/epoch - 9ms/step
# Epoch 218/500
# 2652/2652 - 23s - loss: 1.6686 - val_loss: 1.5502 - 23s/epoch - 9ms/step
# Epoch 219/500
# 2652/2652 - 23s - loss: 1.6983 - val_loss: 1.5480 - 23s/epoch - 9ms/step
# Epoch 220/500
# 2652/2652 - 23s - loss: 1.6907 - val_loss: 1.5354 - 23s/epoch - 9ms/step
# Epoch 221/500
# 2652/2652 - 23s - loss: 1.6385 - val_loss: 1.5504 - 23s/epoch - 9ms/step
# Epoch 222/500
# 2652/2652 - 25s - loss: 1.7021 - val_loss: 1.7307 - 25s/epoch - 9ms/step
# Epoch 223/500
# 2652/2652 - 23s - loss: 1.7078 - val_loss: 1.6328 - 23s/epoch - 9ms/step
# Epoch 224/500
# Restoring model weights from the end of the best epoch: 174.
# 2652/2652 - 23s - loss: 1.7567 - val_loss: 1.6330 - 23s/epoch - 9ms/step
# Epoch 224: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
plt.plot(cnn_history.history['loss'], label='Train loss')
plt.plot(cnn_history.history['val_loss'], label='Validation loss')
fig.legend()
fig.suptitle('CNN')
plt.xlabel("Epochs")
plt.ylabel("MSE")

plt.show()

# %% [markdown]
# Predict and evaluate the validation data. Note, this is on adjusted data.

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

cnn_train_pred = model.predict(x_train)
cnn_valid_pred = model.predict(x_valid)
print('Train rmse:', np.sqrt(mean_squared_error(y_train, cnn_train_pred)))
print('Validation rmse:', np.sqrt(mean_squared_error(y_valid, cnn_valid_pred)))
# Out:
# 2652/2652 [==============================] - 9s 3ms/step
# 663/663 [==============================] - 2s 3ms/step
# Train rmse: 1.1028407886239153
# Validation rmse: 1.2249281744184048

# %%
cnn_train_pred2 = cnn_train_pred.flatten() * y_train_seasonal * y_train_trend
cnn_valid_pred2 = cnn_valid_pred.flatten() * y_valid_seasonal * y_valid_trend

print('Train rmse:', np.sqrt(mean_squared_error(y_train_actual, cnn_train_pred2)))
print('Validation rmse:', np.sqrt(mean_squared_error(y_valid_actual, cnn_valid_pred2)))
# Out:
# Train rmse: 7.3607578653343
# Validation rmse: 7.225074701432652
